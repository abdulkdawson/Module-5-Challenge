# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
athletic_sales_2020_df = pd.read_csv('Resources/athletic_sales_2020.csv')
athletic_sales_2021_df = pd.read_csv('Resources/athletic_sales_2021.csv')

# %%
# Display the 2020 sales DataFrame
athletic_sales_2020_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
athletic_sales_2021_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
athletic_sales_2020_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
athletic_sales_2021_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
athletic_sales_2021_2022_df = pd.concat([athletic_sales_2020_df, athletic_sales_2021_df])
athletic_sales_2021_2022_df  = athletic_sales_2021_2022_df.reset_index(drop=True)

athletic_sales_2021_2022_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9639  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9640       Amazon      1185732     12/31/21  Northeast         Maine
# 9641       Amazon      1185732     12/31/21  Northeast         Maine
# 9642  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Check if any values are null.
athletic_sales_2021_2022_df .isnull().sum()
# Out:
# retailer            0
# retailer_id         0
# invoice_date        0
# region              0
# state               0
# city                0
# product             0
# price_per_unit      0
# units_sold          0
# total_sales         0
# operating_profit    0
# sales_method        0
# dtype: int64

# %%
# Check the data type of each column
athletic_sales_2021_2022_df .dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
athletic_sales_2021_2022_df["invoice_date"] = pd.to_datetime(athletic_sales_2021_2022_df['invoice_date'], format="%m/%d/%y")
athletic_sales_2021_2022_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732   2020-01-01  Northeast      New York
# 1     Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 2     Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 3     Foot Locker      1185732   2020-01-01  Northeast      New York
# 4     Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 9639  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 9640       Amazon      1185732   2021-12-31  Northeast         Maine
# 9641       Amazon      1185732   2021-12-31  Northeast         Maine
# 9642  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Confirm that the "invoice_date" data type has been changed.
athletic_sales_2021_2022_df .dtypes
# Out:
# retailer                    object
# retailer_id                  int64
# invoice_date        datetime64[ns]
# region                      object
# state                       object
# city                        object
# product                     object
# price_per_unit               int64
# units_sold                   int64
# total_sales                  int64
# operating_profit           float64
# sales_method                object
# dtype: object

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".

athletic_sales_grouped = athletic_sales_2021_2022_df.groupby(['region', 'state', 'city'])[["units_sold"]].sum()

athletic_sales_grouped = athletic_sales_grouped.rename(columns={'units_sold': 'Total_Products_Sold'})


# Show the top 5 results.
athletic_sales_grouped = athletic_sales_grouped.sort_values(by='Total_Products_Sold', ascending=False)

athletic_sales_grouped.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Show the number products sold for region, state, and city.
#       2 # Rename the sum to "Total_Products_Sold".
# ----> 4 athletic_sales_grouped = athletic_sales_2021_2022_df.groupby(['region', 'state', 'city'])[["units_sold"]].sum()
#       6 athletic_sales_grouped = athletic_sales_grouped.rename(columns={'units_sold': 'Total_Products_Sold'})
#       9 # Show the top 5 results.
#
# NameError: name 'athletic_sales_2021_2022_df' is not defined

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
athletic_products_sold = pd.pivot_table(athletic_sales_2021_2022_df,
                                index=('region', 'state', 'city'),
                                values='units_sold',
                                aggfunc='sum')

# Rename the "units_sold" column to "Total_Products_Sold"
athletic_products_sold = athletic_products_sold.rename(columns={'units_sold' : 'Total_Products_Sold'})


# Show the top 5 results.

athletic_products_sold.sort_values(by=['Total_Products_Sold'], ascending=False).head(5)
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"
athletic_sales_grouped = athletic_sales_2021_2022_df.groupby(['region', 'state', 'city'])[["total_sales"]].agg(['sum'])

athletic_sales_grouped = athletic_sales_grouped.rename(columns={"total_sales": "Total Sales"})

# Show the top 5 results.

athletic_sales_grouped.sort_values(by=['region'], ascending=True).head(5)
# Out:
#                                  Total Sales
#                                          sum
# region  state        city
# Midwest Illinois     Chicago         9797488
#         Wisconsin    Milwaukee       7727469
#         South Dakota Sioux Falls     8495576
#         Ohio         Columbus       18484583
#         Nebraska     Omaha           5929038

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.

athletic_products_sold = pd.pivot_table(athletic_sales_2021_2022_df,
                                       index=('retailer', 'region', 'state', 'city'),
                                       values='total_sales',
                                       aggfunc='sum')

# Optional: Rename the "total_sales" column to "Total Sales"
athletic_products_sold = athletic_products_sold.rename(columns={'total_sales': 'Total Sales'})

# Show the top 5 results.
athletic_products_sold.sort_values(by=['Total Sales'], ascending=False).head()
# Out:
#                                                     Total Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
athletic_total_sales = athletic_sales_2021_2022_df.groupby(['retailer', 'region', 'state', 'city'])[["total_sales"]].agg(['sum'])

# Rename the "total_sales" column to "Total Sales"
athletic_total_sales = athletic_total_sales.rename(columns={"total_sales": "Total Sales"})

# Show the top 5 results.
athletic_total_sales.sort_values(by=['retailer'], ascending=True).head(5)
# Out:
#                                             Total Sales
#                                                     sum
# retailer region    state         city
# Amazon   Midwest   Ohio          Columbus      16835873
#          Northeast Maine         Portland       8611395
#                    Massachusetts Boston         4193590
#                    New Hampshire Manchester    10077142
#                    Vermont       Burlington    13380463

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
total_sales_by_region = pd.pivot_table(athletic_sales_2021_2022_df,
                                index=['retailer', 'region', 'state', 'city'],
                                values='total_sales',
                                aggfunc='sum')

# Optional: Rename the "total_sales" column to "Total Sales"
total_sales_by_region = total_sales_by_region.rename(columns={'total_sales' : 'Total Sales'})


# Show the top 5 results.
total_sales_by_region.sort_values(by=['Total Sales'], ascending=False).head()
# Out:
#                                                     Total Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
athletic_womens_fw_df = athletic_sales_2021_2022_df.loc[(athletic_sales_2021_2022_df["product"] == "Women's Athletic Footwear")]

athletic_womens_fw_df.head()
# Out:
#        retailer  retailer_id invoice_date     region         state  \
# 21  Foot Locker      1185732   2020-01-04  Northeast      New York
# 22  Foot Locker      1185732   2020-01-04  Northeast      New York
# 23  Foot Locker      1185732   2020-01-04  Northeast      New York
# 26    West Gear      1128299   2020-01-05  Northeast  Pennsylvania
# 27    West Gear      1128299   2020-01-05  Northeast  Pennsylvania
#
#             city                    product  price_per_unit  units_sold  \
# 21      New York  Women's Athletic Footwear              36         281
# 22      New York  Women's Athletic Footwear              41         247
# 23      New York  Women's Athletic Footwear              45         850
# 26  Philadelphia  Women's Athletic Footwear              45         300
# 27  Philadelphia  Women's Athletic Footwear              34          90
#
#     total_sales  operating_profit sales_method
# 21        10116           3742.92       Outlet
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
athletic_womens_fw_df = athletic_sales_2021_2022_df.groupby(['retailer', 'region', 'state', 'city'])[["units_sold"]].agg(['sum'])



# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
athletic_womens_fw_df.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'}, inplace=True)

# Show the top 5 results.
athletic_womens_fw_df.head()
# Out:
#                                             Womens_Footwear_Units_Sold
#                                                                    sum
# retailer region    state         city
# Amazon   Midwest   Ohio          Columbus                        44925
#          Northeast Maine         Portland                        20693
#                    Massachusetts Boston                          11763
#                    New Hampshire Manchester                      26088
#                    Vermont       Burlington                      36476

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.

athletic_womens_fw_df = pd.pivot_table(athletic_sales_2021_2022_df,
                                index=('retailer', 'region', 'state', 'city'),
                                values='units_sold',
                                aggfunc='sum')

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

athletic_womens_fw_df = athletic_womens_fw_df.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'})


# Show the top 5 results.
athletic_womens_fw_df.sort_values(by='Womens_Footwear_Units_Sold', ascending=False).head()
# Out:
#                                                   Womens_Footwear_Units_Sold
# retailer      region    state      city
# West Gear     West      California San Francisco                       81233
# Kohl's        West      California Los Angeles                         74543
# Foot Locker   Northeast New York   New York                            72196
# Sports Direct South     Texas      Dallas                              67683
# Walmart       South     Texas      Houston                             65072

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
most_womens_fw_df = pd.pivot_table(athletic_womens_fw_df, 
                                    index="invoice_date", 
                                    values='total_sales',
                                    aggfunc='sum')

# Optional: Rename the "total_sales" column to "Total Sales"
most_womens_fw_df = most_womens_fw_df.rename(columns={'total_sales' : 'Total Sales'})
# Show the table.
most_womens_fw_df
# Out:
#               Total Sales
# invoice_date
# 2020-01-04         402743
# 2020-01-05         141801
# 2020-01-11         129556
# 2020-01-17         173013
# 2020-01-22         388250
# ...                   ...
# 2021-12-22         200406
# 2021-12-23         808022
# 2021-12-24         190885
# 2021-12-25         315175
# 2021-12-30         167903
#
# [355 rows x 1 columns]

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.
most_womens_fw_df = most_womens_fw_df.resample('D').sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
most_womens_fw_df.sort_values(by='Total Sales', ascending=False).head()
# Out:
#               Total Sales
# invoice_date
# 2021-07-16        1521825
# 2021-12-16        1473497
# 2021-06-17        1376988
# 2021-08-17        1086294
# 2021-07-23        1021806

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.
most_womens_fw_df = most_womens_fw_df.resample('W').sum()


# Sort the resampled pivot table in ascending order on "Total Sales".
most_womens_fw_df.sort_values(by='Total Sales', ascending=False).head()
# Out:
#               Total Sales
# invoice_date
# 2021-12-19        3098970
# 2021-12-12        2922161
# 2021-07-11        2835078
# 2021-07-18        2801449
# 2021-11-14        2531721
